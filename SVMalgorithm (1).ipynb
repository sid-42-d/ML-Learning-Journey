# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
iris=datasets.load_iris()

# %%
X=iris.data
y=iris.target
names=iris.target_names

# %%
X.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %%
df=pd.DataFrame(X, columns=iris.feature_names)
df['species']=iris.target
df['species']=df['species'].replace(to_replace=[1,2,3] , value=['setpsa' , 'vesicolor' , 'virginica'])

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0            0
# ...

# %%
import seaborn as sns
sns.pairplot(data=df , hue='species' , palette='Set2')

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test=train_test_split(X , y , test_size=0.2 , random_state=1)

# %%
print(X_train.shape ,y_train.shape)
print(X_test.shape , y_test.shape)
# Out:
# (120, 4) (120,)
# (30, 4) (30,)

# %%
from sklearn.svm import SVC
svm=SVC(kernel='linear' , random_state=0)
svm.fit(X_train , y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
pred=svm.predict(X_test)

# %%
pred
# Out:
# array([0, 1, 1, 0, 2, 1, 2, 0, 0, 2, 1, 0, 2, 1, 1, 0, 1, 1, 0, 0, 1, 1,
#        1, 0, 2, 1, 0, 0, 1, 2])

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

accuracy_score(y_test , pred)
# Out:
# 1.0

# %%
confusion_matrix(y_test , pred)
# Out:
# array([[11,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0,  6]])

# %%
rbf_svm=SVC(kernel='rbf' , random_state=0)
rbf_svm.fit(X_train , y_train)
rbf_pred=rbf_svm.predict(X_test)

# %%
accuracy_score(y_test , rbf_pred)
# Out:
# 0.9666666666666667

# %%
sigmoid_svm=SVC(kernel='sigmoid' , random_state=0)
sigmoid_svm.fit(X_train , y_train)
sigmoid_pred=sigmoid_svm.predict(X_test)

# %%
accuracy_score(y_test , sigmoid_pred)
# Out:
# 0.2
