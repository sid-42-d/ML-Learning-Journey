# %% [markdown]
# #This is my first juypter lab
# This is a markdown cell I can write her bold italic and many more.

# %%
print("Hello , jupyter")
# Out:
# Hello , jupyter

# %%
print ("This is a code cell")
# Out:
# This is a code cell

# %%
variable="Right in the string"
print(variable)
# Out:
# Right in the string

# %%
variable="Right in the string"
print(f"f string allows you to embed variables {variable}")
# Out:
# f string allows you to embed variables Right in the string

# %%
name="Siddhant Pastapure"
course="Andrew ng ml course"
weak =1
print(f"My name is {name}.")
print(f"I am taking the course of {course}.")
print(f"This is week {weak}.")
# Out:
# My name is Siddhant Pastapure.
# I am taking the course of Andrew ng ml course.
# This is week 1.

# %%
x=5
y=10
result=x+y

print(f"{x}+{y}={result}")
print(f"The square of x is {x*x}")
# Out:
# 5+10=15
# The square of x is 25

# %%
model = "Linear Regression"
accuracy = 0.85
dataset_size = 1000
print(f"Model: {model}")
print(f"Accuracy: {accuracy}")
print(f"Dataset contains {dataset_size} samples")
# Out:
# Model: Linear Regression
# Accuracy: 0.85
# Dataset contains 1000 samples
